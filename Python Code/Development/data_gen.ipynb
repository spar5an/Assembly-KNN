# %% [markdown]
# # Generates Blobbed Data for testing

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples=10000, centers=2, n_features=3, random_state=1)

# %%
def scale_and_cast(data):
    for i in range(0,data.shape[1]):
        sf = 255/(max(data[:,i]) - min(data[:,i]))
        data[:,i] = (data[:,i] - min(data[:,i])) * sf

    return np.rint(data)

# %%
for item, label in zip(scale_and_cast(X),y):
    for num in item:
        print(hex(int(num)), end=", ")
    print(label)
# Out:
# 0x43, 0x2a, 0x87, 1
# 0xa0, 0xc3, 0x72, 0
# 0x80, 0x2e, 0xae, 1
# 0x6c, 0x3b, 0xd1, 1
# 0x9b, 0xbb, 0x83, 0
# 0x5b, 0x47, 0x99, 1
# 0x69, 0x34, 0x8c, 1
# 0x81, 0x3c, 0x8d, 1
# 0x34, 0x20, 0x92, 1
# 0x64, 0x19, 0x9e, 1
# 0x72, 0x47, 0x9e, 1
# 0xba, 0xd2, 0x5f, 0
# 0x8d, 0xc7, 0x76, 0
# 0x75, 0xba, 0x68, 0
# 0x76, 0x2e, 0xa8, 1
# 0x72, 0x34, 0x82, 1
# 0x96, 0xdf, 0x3c, 0
# 0x7d, 0xbe, 0x63, 0
# 0x9c, 0xc1, 0x92, 0
# 0x97, 0xbc, 0x73, 0
# 0x31, 0x25, 0x9e, 1
# 0x57, 0x2c, 0x77, 1
# 0x57, 0x17, 0x9f, 1
# 0x3b, 0x18, 0xa2, 1
# 0x6e, 0x38, 0x91, 1
# 0x9e, 0xb4, 0x73, 0
# 0x3d, 0x43, 0x8e, 1
# 0x71, 0x14, 0xca, 1
# 0x90, 0xc0, 0x4a, 0
# 0x99, 0xc1, 0x95, 0
# 0x54, 0x30, 0xbc, 1
# 0xb0, 0xd2, 0x3d, 0
# 0x6b, 0x2d, 0xc7, 1
# 0x34, 0x31, 0x6d, 1
# 0xc2, 0xbe, 0x4f, 0
# 0x99, 0xb7, 0x42, 0
# 0x27, 0x31, 0x83, 1
# 0xb5, 0xd5, 0x4e, 0
# 0x67, 0x4b, 0x8d, 1
# 0x61, 0x2a, 0x9f, 1
# 0xb2, 0xde, 0x75, 0
# 0x70, 0x32, 0xa3, 1
# 0x9c, 0xd2, 0xa9, 0
# 0x56, 0x32, 0x85, 1
# 0x98, 0xe1, 0x44, 0
# ...

# %%
for i in y:
    print(hex(i), end=", ")
# Out:
# 0x1, 0x0, 0x1, 0x1, 0x0, 0x1, 0x1, 0x1, 0x1, 0x1, 0x1, 0x0, 0x0, 0x0, 0x1, 0x1, 0x0, 0x0, 0x0, 0x0, 0x1, 0x1, 0x1, 0x1, 0x1, 0x0, 0x1, 0x1, 0x0, 0x0, 0x1, 0x0, 0x1, 0x1, 0x0, 0x0, 0x1, 0x0, 0x1, 0x1, 0x0, 0x1, 0x0, 0x1, 0x0, 0x0, 0x1, 0x0, 0x1, 0x1, 0x0, 0x0, 0x0, 0x1, 0x0, 0x1, 0x0, 0x1, 0x0, 0x0, 0x0, 0x1, 0x0, 0x0, 0x1, 0x1, 0x1, 0x1, 0x1, 0x0, 0x0, 0x0, 0x1, 0x0, 0x0, 0x0, 0x0, 0x0, 0x1, 0x0, 0x0, 0x0, 0x1, 0x1, 0x0, 0x1, 0x1, 0x1, 0x0, 0x0, 0x0, 0x0, 0x1, 0x1, 0x0, 0x0, 0x1, 0x1, 0x1, 0x1, 0x1, 0x1, 0x1, 0x0, 0x0, 0x0, 0x1, 0x0, 0x0, 0x0, 0x1, 0x1, 0x1, 0x0, 0x0, 0x1, 0x0, 0x0, 0x0, 0x0, 0x0, 0x0, 0x1, 0x1, 0x0, 0x1, 0x1, 0x1, 0x1, 0x1, 0x1, 0x1, 0x0, 0x1, 0x1, 0x0, 0x1, 0x1, 0x0, 0x1, 0x1, 0x0, 0x0, 0x0, 0x1, 0x0, 0x1, 0x1, 0x0, 0x0, 0x1, 0x0, 0x1, 0x1, 0x1, 0x1, 0x1, 0x1, 0x1, 0x0, 0x1, 0x0, 0x1, 0x0, 0x1, 0x0, 0x0, 0x1, 0x1, 0x0, 0x0, 0x1, 0x1, 0x1, 0x1, 0x0, 0x0, 0x1, 0x0, 0x0, 0x0, 0x1, 0x1, 0x1, 0x0, 0x1, 0x0, 0x0, 0x0, 0x1, 0x1, 0x0, 0x1, 0x1, 0x1, 0x0, 0x0, 0x0, 0x0, 0x1
# ...

# %%
plt.scatter(X[y==0][:,0],X[y==0][:,1])
plt.scatter(X[y==1][:,0],X[y==1][:,1])

# %%
plt.scatter(X[y==0][:,0],X[y==0][:,2])
plt.scatter(X[y==1][:,0],X[y==1][:,2])

# %%
plt.scatter(X[y==0][:,1],X[y==0][:,2])
plt.scatter(X[y==1][:,1],X[y==1][:,2])

# %%
points = [150,250,30]#should be classified as zero
for point in points:
    print(hex(point))
# Out:
# 0x96
# 0xfa
# 0x1e

# %%
import pickle
data = {"values":X, "labels":y}

with open('data.pickle', 'wb') as handle:
    pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)
